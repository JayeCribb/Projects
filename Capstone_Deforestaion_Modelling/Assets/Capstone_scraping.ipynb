# %% [markdown]
# ## Capstone - Data Scraping

# %%
# Import Libraries

import pandas as pd
import numpy as np
import json
import urllib
import requests
import re
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import urllib2
from urllib2 import urlopen
from bs4 import BeautifulSoup
import html5lib
from selenium import webdriver
import time
import string

# %% [markdown]
# ### Country Code Scraping

# %%
# Country Code Scraping - Country codes are needed in order to scrape data for individual countries

country_url = 'http://www.nationsonline.org/oneworld/country_code_list.htm'
driver = webdriver.Chrome('/Users/jayecribb/Downloads/chromedriver')
driver.get(country_url)
htmlSource = driver.page_source
soup = BeautifulSoup(htmlSource,'html5lib' )
# Get codes from soup
# Country codes are contained within a td tag with "text-align:center"
tds = soup.findAll('td', style = "text-align:center" ) 
country_codes = []

for td in tds[1::3]: # Country codes are in every third position 
    country_codes.append(td.text)

# %% [markdown]
# ### Global Forest Watch Scraping

# %% [markdown]
# This webpage has dynamical content so in order to scrape it we need to use the library Selenium. Using the Webdriver, it will automatically open up the webpage as though we are using a browser and scrape through the dynamical content

# %% [markdown]
# #### Scraping functions for specified data

# %%
def tree_cover_value(soup):
    try:
        return soup.find('div', class_='tree-cover').find('span').string + soup.find('div', class_='tree-cover').find('span').findNext('span').text
    except:
        return np.nan

# %%
def total_area_percent(soup):
    try:
        return soup.find('div', class_='total-area').find('span', class_='amount').string
    except:
        return np.nan

# %%
def total_loss(soup):
    try:
        return soup.find('div', class_='total-loss').contents[0]
    except:
        return np.nan

# %%
def total_loss_14(soup):
    try:
        return soup.find('div', class_='graph-amount').find('span').text
    except:
        return np.nan

# %%
def total_gain(soup):
    try:
        return soup.find('div', class_="graph-amount graph-gain-amount").find('span').text
    except:
        return np.nan

# %%
def natural(soup):
    try:
        return soup.find('div', class_ = 'forests-type-graph').findAll('text')[0].text
    except:
        return np.nan

# %%
def primary(soup):
    try:
        return soup.find('div', class_ = 'forests-type-graph').findAll('text')[1].text
    except:
        return np.nan

# %%
def planted(soup):
    try:
        return soup.find('div', class_ = 'forests-type-graph').findAll('text')[2].text
    except:
        return np.nan

# %%
def loss_outside_plantation(soup):
    try:
        return soup.find('p', class_ = "plantations-loss").text
    except:
        return np.nan

# %%
def loss_outside_plantation_per(soup):
    try:
        return soup.find('p', class_ = "plantations-percentage").text
    except:
        return np.nan

# %%
def certified_forest(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[1].find('span').text
    except:
        return np.nan

# %%
def total_economy(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[2].findAll('span')[0].text
    except:
        return np.nan

# %%
def percentage_economy(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[2].findAll('span')[1].text
    except:
        return np.nan

# %%
def employment(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[3].text
    except:
        return np.nan

# %%
def reforestation_rate_10(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[4].find('span').text
    except:
        return np.nan

# %%
def carbon(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[5].find('span').text
    except:
        return np.nan

# %%
def GHG_emissions(soup):
    sections = soup.findAll('h3', class_="section-title" )
    try:
        return sections[6].find('span').text
    except:
        return np.nan

# %%
def conventions(soup):
    
    convention = []
    
    try:
        conventions = soup.find('section', class_="country-section country-conventions-section" ).findAll('span')
        for i in conventions:
            convention.append(i.text)

        return convention
    except:
        return [np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan]

# %% [markdown]
# ### Scraping

# %% [markdown]
# Scraping needs to be implented in batches due to the computing power of my laptop. Scraping is done in batches of 20, each time creating a new data frame and saving to csv. Due to the output of the Conventions function, this will need to be scraped to a seperate data frame and eventually joined to the others.

# %%
# Scrape Function

data = []

for country in country_codes[240:]:
    url_template = 'http://www.globalforestwatch.org/country/'+ country
    driver = webdriver.Chrome('/Users/jayecribb/Downloads/chromedriver')
    
    try:
        driver.get(url_template)
        htmlSource = driver.page_source
        soup = BeautifulSoup(htmlSource,'html5lib' )
        data.append([country, tree_cover_value(soup), total_area_percent(soup), total_loss_14(soup),
              total_gain(soup), natural(soup), primary(soup), planted(soup), loss_outside_plantation(soup),
              loss_outside_plantation_per(soup),certified_forest(soup), total_economy(soup),
              percentage_economy(soup), employment(soup), reforestation_rate_10(soup),
              carbon(soup), GHG_emissions(soup)])
        time.sleep(2)
    except:
        pass
        
df = pd.DataFrame(data)
df.to_csv('data13.csv', encoding = 'utf-8', header = False)

# %%
# Scrape conventions seperatley

data = []

for country in country_codes[240:]:
    url_template = 'http://www.globalforestwatch.org/country/'+ country
    driver = webdriver.Chrome('/Users/jayecribb/Downloads/chromedriver')
    
    try:
        driver.get(url_template)
        htmlSource = driver.page_source
        soup = BeautifulSoup(htmlSource,'html5lib' )
        data.append(conventions(soup))
        time.sleep(2)
    except:
        pass
        
df = pd.DataFrame(data)
df.to_csv('convention13.csv', encoding = 'utf-8', header = False)

# %%
# Read and concatinate scraped files
df01 = pd.read_csv('data01.csv', header = None)
df02 = pd.read_csv('data02.csv', header = None)
df03 = pd.read_csv('data03.csv', header = None)
df04 = pd.read_csv('data04.csv', header = None)
df05 = pd.read_csv('data05.csv', header = None)
df06 = pd.read_csv('data06.csv', header = None)
df07 = pd.read_csv('data07.csv', header = None)
df08 = pd.read_csv('data08.csv', header = None)
df09 = pd.read_csv('data09.csv', header = None)
df10 = pd.read_csv('data10.csv', header = None)
df11 = pd.read_csv('data11.csv', header = None)
df12 = pd.read_csv('data12.csv', header = None)
df13 = pd.read_csv('data13.csv', header = None)
all_data = pd.concat([df01,df02,df03,df04,df05,df06,df07,df08,df09,df10,df11,df12,df13 ])
all_data.drop(0, axis = 1, inplace = True)

# %%
# Defining feature names

all_data.columns = ['country', 'tree_cover', 'tree_cover_%_2000', 'tree_cover_loss_2014',
                       'cover_gain', 'forest_type_nat', 'forest_type_pri', 'forest_type_pla',
                       'loss_outside_plant', 'loss_outside_plant_%','certified_forest', 'total_economy',
                       'percentage_economy', 'employment', 'reforestation_rate_10','carbon',
                       'GHG_emissions']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-243-6997d2fec953> in <module>()
#       3                        'loss_outside_plant', 'loss_outside_plant_%','certified_forest', 'total_economy',
#       4                        'percentage_economy', 'employment', 'reforestation_rate_10','carbon',
# ----> 5                        'GHG_emissions']
#
# /Users/jayecribb/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __setattr__(self, name, value)
#    2755         try:
#    2756             object.__getattribute__(self, name)
# -> 2757             return object.__setattr__(self, name, value)
#    2758         except AttributeError:
#    2759             pass
#
# pandas/src/properties.pyx in pandas.lib.AxisProperty.__set__ (pandas/lib.c:44336)()
#
# /Users/jayecribb/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _set_axis(self, axis, labels)
#     446
#     447     def _set_axis(self, axis, labels):
# --> 448         self._data.set_axis(axis, labels)
#     449         self._clear_item_cache()
#     450
#
# /Users/jayecribb/anaconda/lib/python2.7/site-packages/pandas/core/internals.pyc in set_axis(self, axis, new_labels)
#    2779             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    2780                              'new values have %d elements' %
# -> 2781                              (old_len, new_len))
#    2782
#    2783         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 18 elements, new values have 17 elements

# %%
# Save concatinated data frames to csv. After inspecting this data frame a few features needed ammending. 
# This was implemented in Excel as the data frame wasn't too large 

all_data.to_csv('all_data.csv')

# %%
# Loading in ammended data frame

all_data = pd.read_excel('new_data.xlsx')

# %%
# Read and concatinate convention data frames

dfc01 = pd.read_csv('convention01.csv', header = None)
dfc02 = pd.read_csv('convention02.csv', header = None)
dfc03 = pd.read_csv('convention03.csv', header = None)
dfc04 = pd.read_csv('convention04.csv', header = None)
dfc05 = pd.read_csv('convention05.csv', header = None)
dfc06 = pd.read_csv('convention06.csv', header = None)
dfc07 = pd.read_csv('convention07.csv', header = None)
dfc08 = pd.read_csv('convention08.csv', header = None)
dfc09 = pd.read_csv('convention09.csv', header = None)
dfc10 = pd.read_csv('convention10.csv', header = None)
dfc11 = pd.read_csv('convention11.csv', header = None)
dfc12 = pd.read_csv('convention12.csv', header = None)
dfc13 = pd.read_csv('convention13.csv', header = None)
conventions = pd.concat([dfc01,dfc02,dfc03,dfc04,dfc05,dfc06,dfc07,dfc08,dfc09,dfc10,dfc11,dfc12,dfc13 ])
conventions.drop(0, axis = 1, inplace = True)
conventions.columns = ['CBD', 'UNFCCC', 'KYOTO', 'UNCCD', 'ITTA', 'CITES', 'RAMSAR', 'WORLD HERITAGE',
                      'NLBI', 'ILO 169']

# %%
# Merging the two data frames by index

conventions.reset_index(inplace=True)
conventions.drop('index', inplace = True, axis = 1)
all_data.reset_index(inplace=True)
first_merge = pd.concat([all_data, conventions], axis = 1)

# %%
conventions
# Out:
#               CBD             UNFCCC         KYOTO         UNCCD  \
# 0    Ratification  Non-Annex I Party     Accession     Accession
# 1             NaN                NaN           NaN           NaN
# 2       Accession  Non-Annex I Party     Accession     Accession
# 3    Ratification  Non-Annex I Party     Accession  Ratification
# 4             NaN                NaN           NaN           NaN
# 5             NaN                NaN           NaN           NaN
# 6    Ratification  Non-Annex I Party     Accession  Ratification
# 7             NaN                NaN           NaN           NaN
# 8             NaN                NaN           NaN           NaN
# 9             NaN                NaN           NaN           NaN
# 10   Ratification  Non-Annex I Party  Ratification  Ratification
# 11     Acceptance  Non-Annex I Party     Accession  Ratification
# 12            NaN                NaN           NaN           NaN
# 13   Ratification   Annex I/II Party  Ratification  Ratification
# 14   Ratification   Annex I/II Party  Ratification     Accession
# 15       Approval  Non-Annex I Party     Accession     Accession
# 16   Ratification  Non-Annex I Party     Accession     Accession
# 17            NaN                NaN           NaN           NaN
# 18   Ratification  Non-Annex I Party     Accession  Ratification
# 19            NaN                NaN           NaN           NaN
# 20   Ratification      Annex I Party     Accession     Accession
# 21   Ratification   Annex I/II Party  Ratification     Accession
# 22   Ratification  Non-Annex I Party     Accession     Accession
# 23   Ratification  Non-Annex I Party     Accession  Ratification
# 24            NaN                NaN           NaN           NaN
# 25   Ratification  Non-Annex I Party     Accession     Accession
# 26   Ratification  Non-Annex I Party  Ratification  Ratification
# 27      Accession  Non-Annex I Party     Accession     Accession
# 28   Ratification  Non-Annex I Party     Accession  Ratification
# 29            NaN                NaN           NaN           NaN
# ..            ...                ...           ...           ...
# 217     Accession  Non-Annex I Party     Accession     Accession
# 218  Ratification  Non-Annex I Party     Accession  Ratification
# 219     Non-Party  Non-Annex I Party  Ratification     Accession
# 220     Accession  Non-Annex I Party     Accession     Accession
# 221    Acceptance  Non-Annex I Party     Accession  Ratification
# 222           NaN                NaN           NaN           NaN
# 223           NaN                NaN           NaN           NaN
# 224  Ratification  Non-Annex I Party  Ratification     Accession
# 225  Ratification  Non-Annex I Party     Accession  Ratification
# 226  Ratification      Annex I Party     Accession  Ratification
# 227     Accession  Non-Annex I Party  Ratification  Ratification
# 228           NaN                NaN           NaN           NaN
# 229           NaN                NaN           NaN           NaN
# 230  Ratification  Non-Annex I Party     Accession     Accession
# 231  Ratification      Annex I Party  Ratification     Accession
# 232  Ratification  Non-Annex I Party     Accession     Accession
# 233  Ratification   Annex I/II Party  Ratification  Ratification
# 234     Non-Party   Annex I/II Party     Signature  Ratification
# 235           NaN                NaN           NaN           NaN
# 236  Ratification  Non-Annex I Party  Ratification     Accession
# 237     Accession  Non-Annex I Party  Ratification  Ratification
# 238  Ratification  Non-Annex I Party     Accession  Ratification
# 239  Ratification  Non-Annex I Party     Accession     Accession
# 240  Ratification  Non-Annex I Party  Ratification     Accession
# 241           NaN                NaN           NaN           NaN
# 242           NaN                NaN           NaN           NaN
# 243           NaN                NaN           NaN           NaN
# 244  Ratification  Non-Annex I Party     Accession     Accession
# 245  Ratification  Non-Annex I Party  Ratification  Ratification
# 246  Ratification  Non-Annex I Party     Accession  Ratification
#
#                  ITTA         CITES             RAMSAR WORLD HERITAGE  \
# 0          Non Member     Accession          Non Party   Ratification
# 1                 NaN           NaN                NaN            NaN
# 2    Consuming Member     Accession  Contracting Party   Ratification
# 3          Non Member     Accession  Contracting Party   Ratification
# 4                 NaN           NaN                NaN            NaN
# 5                 NaN           NaN                NaN            NaN
# 6          Non Member     Non Party          Non Party   Ratification
# 7                 NaN           NaN                NaN            NaN
# 8                 NaN           NaN                NaN            NaN
# 9                 NaN           NaN                NaN            NaN
# 10         Non Member  Ratification  Contracting Party     Acceptance
# 11         Non Member     Accession  Contracting Party     Succession
# 12                NaN           NaN                NaN            NaN
# 13   Consuming Member  Ratification  Contracting Party   Ratification
# 14   Consuming Member     Accession  Contracting Party   Ratification
# 15         Non Member     Accession  Contracting Party   Ratification
# 16         Non Member     Accession  Contracting Party      Non Party
# 17                NaN           NaN                NaN            NaN
# 18         Non Member  Ratification  Contracting Party     Acceptance
# 19                NaN           NaN                NaN            NaN
# 20         Non Member     Accession  Contracting Party   Ratification
# 21   Consuming Member  Ratification  Contracting Party   Ratification
# 22         Non Member    Succession  Contracting Party   Ratification
# 23   Producing Member     Accession  Contracting Party   Ratification
# 24                NaN           NaN                NaN            NaN
# 25         Non Member     Accession          Non Party   Ratification
# 26         Non Member  Ratification  Contracting Party   Ratification
# 27         Non Member     Accession  Contracting Party     Succession
# 28         Non Member     Accession  Contracting Party     Acceptance
# 29                NaN           NaN                NaN            NaN
# ..                ...           ...                ...            ...
# 217        Non Member     Non Party  Contracting Party     Succession
# 218        Non Member  Ratification  Contracting Party   Ratification
# 219        Non Member  Ratification  Contracting Party     Acceptance
# 220        Non Member     Non Party          Non Party      Non Party
# 221  Producing Member  Ratification  Contracting Party     Acceptance
# 222               NaN           NaN                NaN            NaN
# 223               NaN           NaN                NaN            NaN
# 224  Producing Member     Accession  Contracting Party   Ratification
# 225        Non Member  Ratification  Contracting Party   Ratification
# 226        Non Member     Accession  Contracting Party   Ratification
# 227        Non Member     Non Party  Contracting Party     Succession
# 228               NaN           NaN                NaN            NaN
# 229               NaN           NaN                NaN            NaN
# 230        Non Member     Accession  Contracting Party     Acceptance
# 231        Non Member     Accession  Contracting Party   Ratification
# 232        Non Member     Accession  Contracting Party      Accession
# 233  Consuming Member  Ratification  Contracting Party   Ratification
# 234  Consuming Member  Ratification  Contracting Party   Ratification
# 235               NaN           NaN                NaN            NaN
# 236        Non Member  Ratification  Contracting Party     Acceptance
# 237        Non Member     Accession  Contracting Party     Succession
# 238        Non Member     Accession          Non Party   Ratification
# 239        Non Member  Ratification  Contracting Party     Acceptance
# 240        Non Member     Accession  Contracting Party     Acceptance
# 241               NaN           NaN                NaN            NaN
# 242               NaN           NaN                NaN            NaN
# 243               NaN           NaN                NaN            NaN
# 244        Non Member     Accession  Contracting Party   Ratification
# 245        Non Member     Accession  Contracting Party   Ratification
# 246        Non Member     Accession          Non Party   Ratification
#
#              NLBI       ILO 169
# 0    Member State  Not Ratified
# 1             NaN           NaN
# 2    Member State  Not Ratified
# 3    Member State  Not Ratified
# 4             NaN           NaN
# 5             NaN           NaN
# 6    Member State  Not Ratified
# 7             NaN           NaN
# 8             NaN           NaN
# 9             NaN           NaN
# 10   Member State  Ratification
# 11   Member State  Not Ratified
# 12            NaN           NaN
# 13   Member State  Not Ratified
# 14   Member State  Not Ratified
# 15   Member State  Not Ratified
# 16   Member State  Not Ratified
# 17            NaN           NaN
# 18   Member State  Not Ratified
# 19            NaN           NaN
# 20   Member State  Not Ratified
# 21   Member State  Not Ratified
# 22   Member State  Not Ratified
# 23   Member State  Not Ratified
# 24            NaN           NaN
# 25   Member State             -
# 26   Member State  Ratification
# 27   Member State  Not Ratified
# 28   Member State  Not Ratified
# 29            NaN           NaN
# ..            ...           ...
# 217  Member State  Not Ratified
# 218  Member State  Not Ratified
# 219  Member State  Not Ratified
# 220  Member State  Not Ratified
# 221  Member State  Not Ratified
# 222           NaN           NaN
# 223           NaN           NaN
# 224  Member State  Not Ratified
# 225  Member State  Not Ratified
# 226  Member State  Not Ratified
# 227  Member State  Not Ratified
# 228           NaN           NaN
# 229           NaN           NaN
# 230  Member State  Not Ratified
# 231  Member State  Not Ratified
# 232  Member State  Not Ratified
# 233  Member State  Not Ratified
# 234  Member State  Not Ratified
# 235           NaN           NaN
# 236  Member State  Not Ratified
# 237  Member State  Not Ratified
# 238  Member State  Not Ratified
# 239  Member State  Ratification
# 240  Member State  Not Ratified
# 241           NaN           NaN
# 242           NaN           NaN
# 243           NaN           NaN
# 244  Member State  Not Ratified
# 245  Member State  Not Ratified
# 246  Member State  Not Ratified
#
# [247 rows x 10 columns]

# %%
#all_data.to_csv('country_names_data.csv', encoding = 'utf-8')

# %% [markdown]
# Another data set to be included is economic data, aggregated by country. This data was collected from http://data.worldbank.org/ and downloaded as a csv file

# %%
# Reading economic data
economics = pd.read_csv('economic_data.csv')

# %%
# Merge and save to csv
second_merge = first_merge.merge(economics, how = 'inner', left_on='country_name', right_on='Country' )
second_merge.to_csv('final_data.csv', encoding = 'utf-8')

# %%
#all_data.to_csv('country_names_data.csv', encoding = 'utf-8')

# %%
# Import data to Local Postgres Database
import psycopg2
import sqlalchemy
from sqlalchemy import create_engine

engine = create_engine('postgresql://jayecribb@localhost:5432/capstone')
economics.to_sql('economics',  engine, if_exists='replace')
conventions.to_sql('conventions',  engine, if_exists='replace')
all_data.to_sql('forests',  engine, if_exists='replace')

# %%
all_data[all_data['country_code']=='GBR']
# Out:
#        country_name country_code tree_cover  tree_cover_%_2000  \
# 233  United Kingdom          GBR     3.6MHa                NaN
#
#      tree_cover_loss_2014  cover_gain  forest_type_nat  forest_type_pri  \
# 233                   NaN         NaN             0.23              NaN
#
#      forest_type_pla loss_outside_plant  loss_outside_plant_%  \
# 233             0.77                NaN                   NaN
#
#     certified_forest    total_economy percentage_economy  \
# 233    2,949,464 ha   USD 9.5 billion   0.4% of the GDP.
#
#                                             employment reforestation_rate_10  \
# 233  134 thousand people are directly employed by t...           14 kha/year
#
#                                        carbon GHG_emissions
# 233  237 million metric tons of carbon stocks           NaN

# %%
data = []


url_template = 'http://www.globalforestwatch.org/country/'+ 'SDN'
driver = webdriver.Chrome('/Users/jayecribb/Downloads/chromedriver')

try:
    driver.get(url_template)
    htmlSource = driver.page_source
    soup = BeautifulSoup(htmlSource,'html5lib' )
    data.append([country, tree_cover_value(soup), total_area_percent(soup), total_loss_14(soup),
          total_gain(soup), natural(soup), primary(soup), planted(soup), loss_outside_plantation(soup),
          loss_outside_plantation_per(soup),certified_forest(soup), total_economy(soup),
          percentage_economy(soup), employment(soup), reforestation_rate_10(soup),
          carbon(soup), GHG_emissions(soup)])
    time.sleep(2)
except:
    pass

# %%
data
# Out:
# [[u'ZWE',
#   u'74KHa',
#   u'0',
#   u'4',
#   u'8',
#   u'61%',
#   u'7%',
#   u'32%',
#   nan,
#   nan,
#   u'0 ha ',
#   u'USD 117.2 million',
#   u'0.2% of the GDP.',
#   u'5 thousand people are directly employed by the forestry sector, according to 2011 FAO data.',
#   u'5940 kha/year',
#   u'153 million metric tons of carbon stocks',
#   u'16.2% of GHG emissions']]
